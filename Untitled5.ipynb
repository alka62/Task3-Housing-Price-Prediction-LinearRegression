# %% [markdown]
# <a href="https://colab.research.google.com/github/alka62/Task3-Housing-Price-Prediction-LinearRegression/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Linear Regression Task - With File Upload

# Step 1: Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# Step 2: Upload Dataset
from google.colab import files
uploaded = files.upload()

# Assuming only one file is uploaded
for filename in uploaded.keys():
    df = pd.read_csv(filename)

    # Step 3: Data Preprocessing
    df = df.dropna()  # Remove missing values
    print("Sample data:\n", df.head())

    # Step 4: Feature Selection
    # Simple Regression
    X_simple = df[['area']]
    y = df['price']

    # Multiple Regression
    X_multi = df[['area', 'bedrooms', 'bathrooms']]

    # Step 5: Train-Test Split
    X_train_s, X_test_s, y_train_s, y_test_s = train_test_split(X_simple, y, test_size=0.2, random_state=42)
    X_train_m, X_test_m, y_train_m, y_test_m = train_test_split(X_multi, y, test_size=0.2, random_state=42)

    # Step 6: Train Models
    model_simple = LinearRegression()
    model_simple.fit(X_train_s, y_train_s)

    model_multi = LinearRegression()
    model_multi.fit(X_train_m, y_train_m)

    # Step 7: Evaluate
    y_pred_s = model_simple.predict(X_test_s)
    y_pred_m = model_multi.predict(X_test_m)

    print("\nSimple Linear Regression Evaluation:")
    print("MAE:", mean_absolute_error(y_test_s, y_pred_s))
    print("MSE:", mean_squared_error(y_test_s, y_pred_s))
    print("R2 Score:", r2_score(y_test_s, y_pred_s))

    print("\nMultiple Linear Regression Evaluation:")
    print("MAE:", mean_absolute_error(y_test_m, y_pred_m))
    print("MSE:", mean_squared_error(y_test_m, y_pred_m))
    print("R2 Score:", r2_score(y_test_m, y_pred_m))

    # Step 8: Plot Simple Regression Line
    plt.scatter(X_test_s, y_test_s, color='blue', label='Actual')
    plt.plot(X_test_s, y_pred_s, color='red', linewidth=2, label='Predicted')
    plt.xlabel('Area')
    plt.ylabel('Price')
    plt.title('Simple Linear Regression: Area vs Price')
    plt.legend()
    plt.grid(True)
    plt.show()

    # Step 9: Print Coefficients
    print("\nSimple Regression Coefficient (Area):", model_simple.coef_[0])
    print("Intercept:", model_simple.intercept_)

    print("\nMultiple Regression Coefficients:")
    for feature, coef in zip(X_multi.columns, model_multi.coef_):
        print(f"{feature}: {coef}")
        print("Intercept:", model_multi.intercept_)
# Out:
#      <input type="file" id="files-34b48fc6-0e57-4e4f-8646-dcb2b4320a8e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-34b48fc6-0e57-4e4f-8646-dcb2b4320a8e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
